# %%
import pandas as pd

# %%
people = {
    "first" : ["Noel", "Tiffanie", "Prashant"],
    "last" : ["Ranjit", "Fabian", "Karki"],
    "email" : ["noelranjit@gmail.com", "tiffanie@gmail.com", "peterparker@gmail.com"]
}

# %%
data = pd.DataFrame(people)
data
# Out:
#       first    last                  email
# 0      Noel  Ranjit   noelranjit@gmail.com
# 1  Tiffanie  Fabian     tiffanie@gmail.com
# 2  Prashant   Karki  peterparker@gmail.com

# %%
# use email as index because they have unique values
data.set_index('email')
# Out:
#                           first    last
# email
# noelranjit@gmail.com       Noel  Ranjit
# tiffanie@gmail.com     Tiffanie  Fabian
# peterparker@gmail.com  Prashant   Karki

# %%
# if we display the dataframe data, it doesnt show any changes
data
# Out:
#       first    last                  email
# 0      Noel  Ranjit   noelranjit@gmail.com
# 1  Tiffanie  Fabian     tiffanie@gmail.com
# 2  Prashant   Karki  peterparker@gmail.com

# %%
# show the changes in the same dataframe
data.set_index("email", inplace = True)
data
# Out:
#                           first    last
# email
# noelranjit@gmail.com       Noel  Ranjit
# tiffanie@gmail.com     Tiffanie  Fabian
# peterparker@gmail.com  Prashant   Karki

# %%
# showing the indexes of the dataframe
data.index
# Out:
# Index(['noelranjit@gmail.com', 'tiffanie@gmail.com', 'peterparker@gmail.com'], dtype='object', name='email')

# %%
# access the email of any user to find their first and last names
data.loc['noelranjit@gmail.com']
# Out:
# first      Noel
# last     Ranjit
# Name: noelranjit@gmail.com, dtype: object

# %%
# displaying only the last name of the first index
data.loc['noelranjit@gmail.com','last']
# Out:
# 'Ranjit'

# %%
data.iloc[0,1]
# Out:
# 'Noel'

# %%
data_new = pd.DataFrame(people)

# %%
data.index[0]
# Out:
# 'noelranjit@gmail.com'

# %%
# resetting the index
data.reset_index(inplace = True)

# %%
data
# Out:
#                    email     first    last
# 0   noelranjit@gmail.com      Noel  Ranjit
# 1     tiffanie@gmail.com  Tiffanie  Fabian
# 2  peterparker@gmail.com  Prashant   Karki

# %%
data.loc[0]
# Out:
# email    noelranjit@gmail.com
# first                    Noel
# last                   Ranjit
# Name: 0, dtype: object

# %%
# Setting respondent as index on survey_results_public.csv
df = pd.read_csv("C:\\Users\\Noel\Downloads\\unzipped_data\\survey_results_public.csv", index_col = "Respondent")
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
# Setting Column from schema as index column
schema = pd.read_csv("C:\\Users\\Noel\Downloads\\unzipped_data\\survey_results_schema.csv", index_col = "Column")
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
# in schema, what does hobbyist mean?
schema.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
schema.loc["MgrIdiot"]
# Out:
# QuestionText    How confident are you that your manager knows ...
# Name: MgrIdiot, dtype: object

# %%
# reading the full description
schema.loc["MgrIdiot", 'QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
# sorting index alphabetically
schema.sort_index(ascending = False, inplace = True)

# %%
schema
# Out:
#                                                     QuestionText
# Column
# YearsCodePro   How many years have you coded professionally (...
# YearsCode      Including any education, how many years have y...
# WorkWeekHrs     On average, how many hours per week do you work?
# WorkRemote                       How often do you work remotely?
# WorkPlan                 How structured or planned is your work?
# ...                                                          ...
# BlockchainOrg  How is your organization thinking about or imp...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BetterLife     Do you think people born today will have a bet...
# Age1stCode     At what age did you write your first line of c...
# Age            What is your age (in years)? If you prefer not...
#
# [85 rows x 1 columns]
